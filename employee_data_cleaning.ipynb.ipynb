# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -------------- ------------------------- 3.7/9.8 MB 20.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 14.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------- ----------------------------- 3.1/12.4 MB 15.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.4 MB 12.1 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.4 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.4 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 12.8 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/employee_data.csv")

# %%
df
# Out:
#     Employee_ID    Name Department   Age  Experience_Years  Monthly_Salary  \
# 0           201   Aarav         IT  25.0                 2         35000.0
# 1           202    Diya         HR  28.0                 4         42000.0
# 2           203   Rohan    Finance  30.0                 6         50000.0
# 3           204   Meera         IT  26.0                 3         38000.0
# 4           205   Arjun  Marketing  29.0                 5         45000.0
# 5           206   Kavya    Finance  31.0                 7         55000.0
# 6           207   Rahul         IT   NaN                 4         41000.0
# 7           208   Priya         HR  27.0                 3             NaN
# 8           209  Vikram  Marketing  32.0                 8         60000.0
# 9           210  Ananya         IT  24.0                 1         32000.0
# 10          211   Kiran    Finance  35.0                10         70000.0
# ...

# %%
df.shape
# Out:
# (16, 7)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        16 non-null     int64
#  1   Name               16 non-null     str
#  2   Department         16 non-null     str
#  3   Age                15 non-null     float64
#  4   Experience_Years   16 non-null     int64
#  5   Monthly_Salary     15 non-null     float64
#  6   Performance_Score  16 non-null     int64
# dtypes: float64(2), int64(3), str(2)
# memory usage: 1.0 KB

# %%
df.isnull().sum()
# Out:
# Employee_ID          0
# Name                 0
# Department           0
# Age                  1
# Experience_Years     0
# Monthly_Salary       1
# Performance_Score    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Employee_ID          0
# Name                 0
# Department           0
# Age                  1
# Experience_Years     0
# Monthly_Salary       1
# Performance_Score    0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#    Employee_ID   Name Department   Age  Experience_Years  Monthly_Salary  \
# 6          207  Rahul         IT   NaN                 4         41000.0
# 7          208  Priya         HR  27.0                 3             NaN
#
#    Performance_Score
# 6                 87
# 7                 84

# %%
df["Age"].mean()
# Out:
# np.float64(28.533333333333335)

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Monthly_Salary"].mean()
# Out:
# np.float64(46066.666666666664)

# %%
df["Monthly_Salary"] = df["Monthly_Salary"].fillna(df["Monthly_Salary"].mean())

# %%
df.isnull().sum()
# Out:
# Employee_ID          0
# Name                 0
# Department           0
# Age                  0
# Experience_Years     0
# Monthly_Salary       0
# Performance_Score    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#     Employee_ID    Name Department   Age  Experience_Years  Monthly_Salary  \
# 15          215  Aditya    Finance  27.0                 3         40000.0
#
#     Performance_Score
# 15                 86

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (15, 7)

# %%
df
# Out:
#     Employee_ID    Name Department        Age  Experience_Years  \
# 0           201   Aarav         IT  25.000000                 2
# 1           202    Diya         HR  28.000000                 4
# 2           203   Rohan    Finance  30.000000                 6
# 3           204   Meera         IT  26.000000                 3
# 4           205   Arjun  Marketing  29.000000                 5
# 5           206   Kavya    Finance  31.000000                 7
# 6           207   Rahul         IT  28.533333                 4
# 7           208   Priya         HR  27.000000                 3
# 8           209  Vikram  Marketing  32.000000                 8
# 9           210  Ananya         IT  24.000000                 1
# 10          211   Kiran    Finance  35.000000                10
# 11          212   Sneha         HR  29.000000                 5
# 12          213   Varun  Marketing  28.000000                 4
# 13          214  Ishita         IT  30.000000                 6
# ...

# %%
X = df[["Age", "Experience_Years", "Monthly_Salary"]]

# %%
y = df["Performance_Score"]

# %%
df.to_csv("cleaned_dataset/cleaned_employee_data.csv", index=False)
